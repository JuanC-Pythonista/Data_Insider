# %%
import requests
import pandas as pd

# %% [markdown]
# ## **2. Obtención de los datos**

# %%
#Apple
# Se lee un archivo .txt donde se encuentra el key privado de la API
with open("InfoIgnore/pass.txt",'r') as f:
    pwd= f.read()
# Se lee el API, se genera el requests y se descargan los datos de la API
url1 = "https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/week/2022-01-01/2022-12-31?adjusted=true&sort=asc&apiKey="+pwd
headers1 = {"Accept-Encoding": "gzip, deflate"}
response1 = requests.get(url1, headers=headers1)
Apple = response1.json()
print(response1)
print(Apple)
Apple.keys()
# Out:
# <Response [200]>
# ...

# %%
DataSetApple= pd.DataFrame(Apple['results'])
DataSetApple.head(10)
# Out:
#              v        vw        o       c         h       l              t  \
# 0  339980123.0  179.0995  177.085  177.57  181.3300  177.07  1640494800000
# 1  481915611.0  177.1385  177.830  172.17  182.9400  171.03  1641099600000
# 2  422544574.0  173.0033  169.080  173.07  177.1800  168.17  1641704400000
# 3  400124342.0  167.1724  171.510  162.41  172.5400  162.30  1642309200000
# 4  688149428.0  161.9512  160.020  170.33  170.3500  154.70  1642914000000
# 5  457896933.0  173.6787  170.160  172.39  176.2399  169.51  1643518800000
# 6  412491545.0  172.9816  172.860  168.64  176.6500  168.04  1644123600000
# 7  363973562.0  169.7229  167.370  167.30  173.3400  166.19  1644728400000
# 8  414279367.0  161.6358  164.980  164.85  166.6900  152.00  1645333200000
# 9  418748277.0  164.8511  163.060  163.17  168.9100  161.97  1645938000000
#
#          n
# 0  2704014
# 1  4130315
# 2  3613640
# 3  3479982
# 4  6337774
# 5  3772842
# 6  3357351
# 7  3135169
# 8  3913514
# 9  3604858

# %%
#Microsoft
# Se lee un archivo .txt donde se encuentra el key privado de la API
with open("InfoIgnore/pass.txt",'r') as f:
    pwd= f.read()
# Se lee el API, se genera el requests y se descargan los datos de la API
url2 = "https://api.polygon.io/v2/aggs/ticker/MSFT/range/1/week/2022-01-01/2022-12-31?adjusted=true&sort=asc&apiKey="+pwd
headers2 = {"Accept-Encoding": "gzip, deflate"}
response2 = requests.get(url2, headers=headers2)
Microsoft = response2.json()
print(response2)
print(Microsoft)
Microsoft.keys()
# Out:
# <Response [200]>
# ...

# %%
DataSetMicros= pd.DataFrame(Microsoft['results'])
DataSetMicros.head(10)
# Out:
#              v        vw        o       c         h        l              t  \
# 0   84640440.0  340.3078  335.460  336.32  344.3000  335.430  1640494800000
# 1  173985587.0  321.7430  335.350  314.04  338.0000  310.090  1641099600000
# 2  193243449.0  311.8137  309.485  310.20  323.4100  303.750  1641704400000
# 3  181503045.0  304.4453  304.070  296.03  313.9093  295.610  1642309200000
# 4  352527629.0  295.7335  292.200  308.26  308.5000  276.050  1642914000000
# 5  202854195.0  307.9229  308.950  305.94  315.1200  299.960  1643518800000
# 6  176675264.0  303.5428  306.170  295.04  311.9300  294.220  1644123600000
# 7  160418384.0  294.4510  293.770  287.93  300.8700  286.305  1644728400000
# 8  169069691.0  287.6950  285.000  297.31  297.6300  271.520  1645333200000
# 9  157402366.0  295.6795  294.310  289.86  303.1300  287.165  1645938000000
#
#          n
# 0  1196308
# 1  2681567
# 2  2851966
# 3  2778370
# 4  5049508
# 5  2852678
# 6  2518482
# 7  2417687
# 8  2583567
# ...

# %%
#Tesla
# Se lee un archivo .txt donde se encuentra el key privado de la API
with open("InfoIgnore/pass.txt",'r') as f:
    pwd= f.read()
# Se lee el API, se genera el requests y se descargan los datos de la API
url3 = "https://api.polygon.io/v2/aggs/ticker/TSLA/range/1/week/2022-01-01/2022-12-31?adjusted=true&sort=asc&apiKey="+pwd
headers3 = {"Accept-Encoding": "gzip, deflate"}
response3 = requests.get(url3, headers=headers3)
Tesla = response3.json()
print(response3)
print(Tesla)
Tesla.keys()
# Out:
# <Response [200]>
# ...

# %%
DataSetTesla= pd.DataFrame(Tesla['results'])
DataSetTesla.head(10)
# Out:
#              v        vw         o         c         h         l  \
# 0  274974996.0  362.2086  357.8900  352.2600  373.0000  351.0500
# 1  458928342.0  371.7844  382.5833  342.3200  402.6667  336.6667
# 2  411424275.0  351.8286  333.3333  349.8700  371.8667  326.6667
# 3  315543468.0  334.9771  342.2017  314.6333  356.9300  313.5000
# 4  624580770.0  295.0465  301.5867  282.1167  329.2300  264.0033
# 5  396660510.0  304.8763  290.9033  307.7733  314.5667  287.3500
# 6  309000771.0  303.8457  307.9300  286.6667  315.9233  283.5667
# 7  300106263.0  295.9868  287.1900  285.6600  308.8100  279.2033
# 8  389752218.0  262.5012  278.0433  269.9567  285.5779  233.3333
# 9  377049954.0  285.7169  271.6700  279.4300  296.6267  271.5692
#
#                t        n
# 0  1640494800000  2803036
# 1  1641099600000  4730833
# 2  1641704400000  4011889
# 3  1642309200000  3351290
# 4  1642914000000  6822698
# 5  1643518800000  3941622
# 6  1644123600000  3301330
# 7  1644728400000  3158118
# ...

# %%
#NVIDIA
# Se lee un archivo .txt donde se encuentra el key privado de la API
with open("InfoIgnore/pass.txt",'r') as f:
    pwd= f.read()
# Se lee el API, se genera el requests y se descargan los datos de la API
url4 = "https://api.polygon.io/v2/aggs/ticker/NVDA/range/1/week/2022-01-01/2022-12-31?adjusted=true&sort=asc&apiKey="+pwd
headers4 = {"Accept-Encoding": "gzip, deflate"}
response4 = requests.get(url4, headers=headers4)
NVIDIA = response4.json()
print(response4)
print(NVIDIA)
NVIDIA.keys()
# Out:
# <Response [200]>
# ...

# %%
DataSetNVIDIA= pd.DataFrame(NVIDIA['results'])
DataSetNVIDIA.head(10)
# Out:
#              v        vw       o       c         h         l              t  \
# 0  174121048.0  301.9570  296.60  294.11  313.3000  293.3057  1640494800000
# 1  228174609.0  285.9871  298.15  272.47  307.1100  270.5700  1641099600000
# 2  231652947.0  271.1252  265.81  269.42  285.9500  256.4384  1641704400000
# 3  206775925.0  249.5387  262.60  233.74  266.3800  232.6300  1642309200000
# 4  345310535.0  224.7878  223.30  228.40  240.5700  208.8800  1642914000000
# 5  239051704.0  244.4144  231.82  243.19  258.1700  230.5200  1643518800000
# 6  242835250.0  253.7967  243.72  239.49  269.2499  237.7300  1644123600000
# 7  344245354.0  250.1017  239.34  236.42  265.8200  231.0000  1644728400000
# 8  246438235.0  231.5662  230.35  241.57  242.1700  208.9000  1645333200000
# 9  207606593.0  237.2924  239.92  229.36  246.6500  224.8200  1645938000000
#
#          n
# 0  2489136
# 1  3681603
# 2  3591545
# 3  3227924
# 4  5111249
# 5  3320679
# 6  3541710
# 7  4874223
# 8  3333658
# ...

# %%
#Intel
# Se lee un archivo .txt donde se encuentra el key privado de la API
with open("InfoIgnore/pass.txt",'r') as f:
    pwd= f.read()
# Se lee el API, se genera el requests y se descargan los datos de la API
url5 = "https://api.polygon.io/v2/aggs/ticker/INTC/range/1/week/2022-01-01/2022-12-31?adjusted=true&sort=asc&apiKey="+pwd
headers5 = {"Accept-Encoding": "gzip, deflate"}
response5 = requests.get(url5, headers=headers5)
Intel = response5.json()
print(response5)
print(Intel)
Intel.keys()
# Out:
# <Response [200]>
# ...

# %%
DataSetIntel= pd.DataFrame(Intel['results'])
DataSetIntel.head(10)
# Out:
#              v       vw      o      c       h        l              t        n
# 0   89134260.0  51.7927  51.35  51.50  52.159  51.3022  1640494800000   523343
# 1  205104738.0  53.8360  51.65  53.44  56.170  51.6000  1641099600000  1217901
# 2  177949685.0  55.2481  53.97  55.70  56.280  53.3100  1641704400000  1169236
# 3  140882681.0  53.5051  55.31  52.04  55.650  51.9400  1642309200000   908946
# 4  314741764.0  49.6664  51.48  47.73  52.720  46.3000  1642914000000  2188581
# 5  196746037.0  48.5167  47.68  48.01  49.685  47.1300  1643518800000  1192794
# 6  160708423.0  48.7809  48.13  47.63  49.970  47.5000  1644123600000   958998
# 7  198737619.0  46.8105  47.92  45.04  48.490  44.5100  1644728400000  1289804
# 8  207242835.0  45.4989  44.69  47.71  47.790  43.6250  1645333200000  1290645
# 9  217450476.0  47.6649  47.00  48.07  48.990  46.2200  1645938000000  1322147
